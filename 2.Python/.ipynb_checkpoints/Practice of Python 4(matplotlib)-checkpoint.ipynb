# %%
# 시각화 기본
import matplotlib.pyplot as plt
import numpy as np

# %%
score = [0, 3.16, 3.77, 3.15, 4.15, 4.5, 3.86] # 데이터 리스트 처리

# %%
plt.plot(score) # 간단한 시각화

# %%
plt.plot(score) # 간단한 시각화
plt.show()      # 위에 시각화만 진행했을때 나오는 지저분한 문구 제거

# %%
# subplot 각각 하나하나 정해줘야함.
fig = plt.figure() # 그림에 대한 종합적인 정보를 담은 객체(크기,비율 지정)
                   # 단, 빈 figure로는 그래프를 그릴 수 없어 add_plot을 사용해 최소 하나 이상 subplot 생성한다

ax1 = fig.add_subplot(2,2, 1)# 2행 2열의 총 네개의 그림중 첫 번째
plt.plot(score)                          # plt는 가장 최근의 fig와 subplot을 그린다.
ax2 = fig.add_subplot(2,2, 2)# 두 번째
plt.plot(score, "y--")                   # k 옵션은 검정색, c 파란색, y는 노란색, m은 빨간색
                                         # "-" 선, "--"실선
ax3 = fig.add_subplot(2,2, 3)# 세 번째
ax3.hist(np.random.randn(50), bins =30, color="m", alpha=0.3) # 히스토그램 bins =그래프 굵기, alpha = 투명도 
ax4 = fig.add_subplot(2,2, 4)# 네 번째다.
ax4.scatter(np.arange(30), np.arange(30) + 3*np.random.randn(30)) 



# 주의) 주피터 노트북은 실행되는 셀마다 그래프가 리셋 되므로
#       복잡한 그래프를 그릴때 단일 노트북 셀에 그래프를 그리는 코드를 전부 입력해야 함.

# %%
# subplots 같은 범위 내에서 데이터를 비교할 경우 유용함. 한 번에 여러개 설정
fig , ax = plt.subplots(2,2)
print(fig) # 전체 subplot ex) 서브플로안에 몇개의 그래프가 있던지 상관없이 그걸 담는 하나. 전체 사이즈
print(ax)  # 전체 중 낱낱개를 말한다 ex) 서브플롯 안에 2개(a1,a2)의 그래프가 있다면 a1, a2 를 일컬음
fig , ax = plt.subplots(2,2, sharex = True, sharey = True) # x,y축을 공유함.
plt.plot(score)
# Out:
# Figure(432x288)
# [[<AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:>]]

# %%
# 마커 표시하기
plt.plot(np.random.randn(30).cumsum(),"ko--")
# 표준편차 0 ~ -1을 갖는 난수 30개를 추출해
# .cumsum을 사용해 약간의 연관성 부여
# "k" 검정색 표현
# "o" 마커 꼭짓점 표시

# %%
plt.plot(score, "k--", label="Default")  
plt.plot(score, "k-" , drawstyle = 'steps-post', label= "steps-post" ) # 라벨을 붙여 각각의 그래프를 정의해줌 
plt.legend(loc='best')  # 가장 적합한 곳에 위치시킴 // 라벨과 레전드를 이용

# %%
# 눈금, 라벨, 범례
data = [-0.05890225,  0.29161088, -0.08744278,  1.17767436,  1.59902222,
        0.19847195, -0.43636889,  0.44200478, -0.82135947,  0.10140094,
       -0.20557414, -1.29963639, -0.36011361, -1.7799116 , -0.69315856,
        0.20203019, -0.3982438 ,  0.08320052, -0.85312217, -1.33535695,
       -0.12365346,  0.72065025, -0.46800591, -2.63499328, -2.73043539,
       -3.53709725, -2.6363851 , -3.29791662, -4.00894314, -3.63792479,
       42.312497  , 41.82156735, 43.33466193, 43.42914253, 43.11689718,
       43.26450532, 45.75032114, 45.80890771, 45.31731975, 45.19189384,
       43.71245632, 43.66135998, 43.56212647, 41.46267485, 40.64950093,
       40.9426551 , 39.83469212, 39.78517502, 39.42092779, 38.78486694,
       37.60403487, 38.33159084, 39.71268096, 38.79391411, 37.96255662,
       37.2992614 , 35.6932223 , 35.21230611, 37.0095916 , 36.02407326,
       35.89333258, 36.30765823, 37.13600558, 35.9273213 , 36.4091135 ,
       36.56698816, 37.22756184, 36.6014499 , 34.99307951, 36.10217504,
       35.42905104, 35.53248393, 34.34475583, 35.73597073, 36.31227869,
       36.91394114, 37.52819199, 39.54913376, 39.65277774, 38.70019085,
       38.73488145, 38.82753129, 38.57162325, 38.04033335, 39.14749528,
       38.63501287, 40.35900334, 39.89820486, 40.94291851, 40.50404308,
       38.72142528, 37.60839471, 38.57053926, 37.17246928, 37.07331052,
       36.98753903, 37.2212322 , 36.40501606, 36.37018933, 34.2338119 ,
       35.00214669, 35.87354481, 35.17552648, 34.12773786, 33.76451537,
       32.79327793, 32.62620617, 33.68480539, 33.68789646, 33.31438776,
       33.19916443, 32.92440331, 33.79483427, 34.36837582, 35.93296696,
       36.68895439, 35.48962557, 36.8385089 , 35.26373567, 35.73618527,
       36.51427592, 36.07597685, 36.47842671, 37.55529757, 38.06008093,
       37.00857144, 35.9180329 , 36.09564177, 35.01128491, 34.85990034,
       34.94610276, 34.73623969, 34.51506144, 36.86236545, 36.54829176,
       36.39907952, 35.99938022, 34.48818354, 34.73792639, 34.18859768,
       35.82461162, 36.98082128, 38.31201065, 37.05320388, 37.22904992,
       36.84590168, 38.49415754, 39.05808094, 39.28328822, 39.66510858,
       38.25878211, 36.84475962, 38.0567705 , 39.95391552, 38.79365071,
       40.54313752, 40.02750471, 39.30387487, 40.81200807, 39.77957803,
       39.54408352, 38.11886453, 36.89428147, 38.35281339, 36.74589008,
       35.30792843, 35.76768764, 34.81909297, 34.69184353, 34.09952696,
       35.47575199, 32.81491298, 33.6203199 , 33.64205366, 33.64957869,
       32.25545141, 32.08341782, 32.70628271, 32.62838922, 31.77300746,
       31.37794244, 31.95109048, 31.60721073, 31.82123508, 33.4249975 ,
       33.40394459, 34.2556197 , 34.27043517, 33.98870514, 34.57564112,
       33.43038401, 34.74413426, 33.81487503, 31.83367451, 32.34141933,
       32.1457281 , 31.65061514, 30.39471726, 31.56397651, 32.69468159,
       32.8092866 , 32.04418381, 31.29134019, 32.1239958 , 31.21427036]

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
plt.plot(data, label = "Default")  
plt.legend(loc = "best")                                                           # 범례 더하기
ax.set_xticks([100,500,1000])                                                      # x 축 범위 정하기
ax.set_xticklabels(["Stage 1","Stage 2","Stage 3"], rotation=20, fontsize="small") # x 축 범위 이름 붙이기
ax.set_xlabel("Stage")                                                             # x 축 이름 붙이기
# Out:
# Text(0.5, 0, 'Stage')
