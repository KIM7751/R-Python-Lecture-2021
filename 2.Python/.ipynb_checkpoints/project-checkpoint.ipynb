# %%
import pandas as pd
from pandas import DataFrame as df

# %%
import pymysql as m

# %%
con = m.connect(host='localhost', user='root', passwd='1234', db='project', charset='utf8')
cur = con.cursor()
q = "select 년_월, 국가, 방문자_수 from project_csv where 국가='China' order by 방문자_수 desc;"
cur.execute(q)
res = cur.fetchall()
col = ["년_월", "국가", "방문자_수"]
df_ch = pd.DataFrame(res, columns = col)
con.close()
df_ch
# Out:
#       년_월     국가   방문자_수
# 0   19-08  China  578112
# 1   19-10  China  567695
# 2   19-09  China  541350
# 3   19-07  China  519132
# 4   19-12  China  508877
# 5   19-11  China  505369
# 6   19-05  China  500413
# 7   19-04  China  493250
# 8   19-03  China  487623
# 9   20-01  China  481681
# 10  19-06  China  475007
# 11  19-02  China  453379
# 12  19-01  China  392814
# 13  20-02  China  104086
# 14  20-03  China   16595
# 15  20-04  China    3935

# %%
df_ch.shape
# Out:
# (15, 3)

# %%
df_ch1 = df_ch.sort_values(by=['년_월'])
df_ch1
# Out:
#       년_월     국가   방문자_수
# 12  19-01  China  392814
# 11  19-02  China  453379
# 8   19-03  China  487623
# 7   19-04  China  493250
# 6   19-05  China  500413
# 10  19-06  China  475007
# 3   19-07  China  519132
# 0   19-08  China  578112
# 2   19-09  China  541350
# 1   19-10  China  567695
# 5   19-11  China  505369
# 4   19-12  China  508877
# 9   20-01  China  481681
# 13  20-02  China  104086
# 14  20-03  China   16595
# 15  20-04  China    3935

# %%
con = m.connect(host='localhost', user='root', passwd='1234', db='project', charset='utf8')
cur = con.cursor()
q = "select 년_월, 국가, 방문자_수 from project_csv where 국가='Japan' order by 방문자_수 desc;"
cur.execute(q)
res = cur.fetchall()
col = ["년_월", "국가", "방문자_수"]
df_jp = pd.DataFrame(res, columns = col)
con.close()
df_jp
# Out:
#       년_월     국가   방문자_수
# 0   19-03  Japan  375119
# 1   19-08  Japan  329652
# 2   19-04  Japan  290092
# 3   19-05  Japan  286273
# 4   19-06  Japan  282476
# 5   19-07  Japan  274830
# 6   19-11  Japan  258522
# 7   19-12  Japan  255356
# 8   19-09  Japan  251119
# 9   19-10  Japan  248541
# 10  19-02  Japan  213200
# 11  20-02  Japan  211199
# 12  19-01  Japan  206526
# 13  20-01  Japan  203969
# 14  20-03  Japan    8347
# 15  20-04  Japan     360

# %%
df_jp.shape
# Out:
# (16, 3)

# %%
df_jp1 = df_jp.sort_values(by=['년_월'])
df_jp1
# Out:
#       년_월     국가   방문자_수
# 12  19-01  Japan  206526
# 10  19-02  Japan  213200
# 0   19-03  Japan  375119
# 2   19-04  Japan  290092
# 3   19-05  Japan  286273
# 4   19-06  Japan  282476
# 5   19-07  Japan  274830
# 1   19-08  Japan  329652
# 8   19-09  Japan  251119
# 9   19-10  Japan  248541
# 6   19-11  Japan  258522
# 7   19-12  Japan  255356
# 13  20-01  Japan  203969
# 11  20-02  Japan  211199
# 14  20-03  Japan    8347
# 15  20-04  Japan     360

# %%
con = m.connect(host='localhost', user='root', passwd='1234', db='project', charset='utf8')
cur = con.cursor()
q = "select 년_월, 국가, 방문자_수 from project_csv where 국가='Taiwan' order by 방문자_수 desc;"
cur.execute(q)
res = cur.fetchall()
col = ["년_월", "국가", "방문자_수"]
df_Tai = pd.DataFrame(res, columns = col)
con.close()
df_Tai
# Out:
#       년_월      국가   방문자_수
# 0   19-10  Taiwan  127944
# 1   19-06  Taiwan  118437
# 2   19-07  Taiwan  113587
# 3   19-04  Taiwan  113072
# 4   20-01  Taiwan  110354
# 5   19-08  Taiwan  109273
# 6   19-09  Taiwan  102758
# 7   19-11  Taiwan  102241
# 8   19-05  Taiwan  101779
# 9   19-03  Taiwan   98510
# 10  19-02  Taiwan   94559
# 11  19-12  Taiwan   90379
# 12  19-01  Taiwan   87954
# 13  20-02  Taiwan   53042
# 14  20-03  Taiwan     585
# 15  20-04  Taiwan     155

# %%
df_Tai1 = df_Tai.sort_values(by=['년_월'])
df_Tai1
# Out:
#       년_월      국가   방문자_수
# 12  19-01  Taiwan   87954
# 10  19-02  Taiwan   94559
# 9   19-03  Taiwan   98510
# 3   19-04  Taiwan  113072
# 8   19-05  Taiwan  101779
# 1   19-06  Taiwan  118437
# 2   19-07  Taiwan  113587
# 5   19-08  Taiwan  109273
# 6   19-09  Taiwan  102758
# 0   19-10  Taiwan  127944
# 7   19-11  Taiwan  102241
# 11  19-12  Taiwan   90379
# 4   20-01  Taiwan  110354
# 13  20-02  Taiwan   53042
# 14  20-03  Taiwan     585
# 15  20-04  Taiwan     155

# %%
con = m.connect(host='localhost', user='root', passwd='1234', db='project', charset='utf8')
cur = con.cursor()
q = "select 년_월, 국가, 방문자_수 from project_csv where 국가='USA' order by 방문자_수 desc;"
cur.execute(q)
res = cur.fetchall()
col = ["년_월", "국가", "방문자_수"]
df_USA = pd.DataFrame(res, columns = col)
con.close()
df_USA
# Out:
#       년_월   국가   방문자_수
# 0   19-06  USA  105398
# 1   19-04  USA  102524
# 2   19-10  USA  101099
# 3   19-07  USA   97428
# 4   19-05  USA   95815
# 5   19-09  USA   90819
# 6   19-08  USA   86586
# 7   19-03  USA   84275
# 8   19-11  USA   82238
# 9   19-12  USA   77387
# 10  20-01  USA   67255
# 11  19-01  USA   62737
# 12  19-02  USA   57732
# 13  20-02  USA   42439
# 14  20-03  USA   10570
# 15  20-04  USA    6417

# %%
df_USA1 = df_USA.sort_values(by=['년_월'])
df_USA1
# Out:
#       년_월   국가   방문자_수
# 11  19-01  USA   62737
# 12  19-02  USA   57732
# 7   19-03  USA   84275
# 1   19-04  USA  102524
# 4   19-05  USA   95815
# 0   19-06  USA  105398
# 3   19-07  USA   97428
# 6   19-08  USA   86586
# 5   19-09  USA   90819
# 2   19-10  USA  101099
# 8   19-11  USA   82238
# 9   19-12  USA   77387
# 10  20-01  USA   67255
# 13  20-02  USA   42439
# 14  20-03  USA   10570
# 15  20-04  USA    6417

# %%
con = m.connect(host='localhost', user='root', passwd='1234', db='project', charset='utf8')
cur = con.cursor()
q = "select 년_월, 국가, 방문자_수 from project_csv where 국가='Hong Kong' order by 방문자_수 desc;"
cur.execute(q)
res = cur.fetchall()
col = ["년_월", "국가", "방문자_수"]
df_HK = pd.DataFrame(res, columns = col)
con.close()
df_HK
# Out:
#       년_월         국가  방문자_수
# 0   19-04  Hong Kong  76104
# 1   19-12  Hong Kong  71751
# 2   20-01  Hong Kong  66962
# 3   19-08  Hong Kong  65958
# 4   19-10  Hong Kong  65544
# 5   19-06  Hong Kong  61728
# 6   19-07  Hong Kong  59036
# 7   19-11  Hong Kong  58600
# 8   19-05  Hong Kong  57026
# 9   19-02  Hong Kong  51312
# 10  19-03  Hong Kong  46068
# 11  19-09  Hong Kong  45911
# 12  19-01  Hong Kong  35896
# 13  20-02  Hong Kong  20966
# 14  20-03  Hong Kong    262
# 15  20-04  Hong Kong     35

# %%
df_HK1 = df_HK.sort_values(by=['년_월'])
df_HK1
# Out:
#       년_월         국가  방문자_수
# 12  19-01  Hong Kong  35896
# 9   19-02  Hong Kong  51312
# 10  19-03  Hong Kong  46068
# 0   19-04  Hong Kong  76104
# 8   19-05  Hong Kong  57026
# 5   19-06  Hong Kong  61728
# 6   19-07  Hong Kong  59036
# 3   19-08  Hong Kong  65958
# 11  19-09  Hong Kong  45911
# 4   19-10  Hong Kong  65544
# 7   19-11  Hong Kong  58600
# 1   19-12  Hong Kong  71751
# 2   20-01  Hong Kong  66962
# 13  20-02  Hong Kong  20966
# 14  20-03  Hong Kong    262
# 15  20-04  Hong Kong     35

# %%
con = m.connect(host='localhost', user='root', passwd='1234', db='project', charset='utf8')
cur = con.cursor()
q = "select 년_월, 국가, 방문자_수 from project_csv where 국가='Thailand' order by 방문자_수 desc;"
cur.execute(q)
res = cur.fetchall()
col = ["년_월", "국가", "방문자_수"]
df_Thai = pd.DataFrame(res, columns = col)
con.close()
df_Thai
# Out:
#       년_월        국가  방문자_수
# 0   19-04  Thailand  69726
# 1   19-10  Thailand  65878
# 2   19-12  Thailand  55850
# 3   19-03  Thailand  53100
# 4   19-05  Thailand  52660
# 5   19-11  Thailand  49998
# 6   19-01  Thailand  41334
# 7   19-02  Thailand  39220
# 8   20-01  Thailand  38466
# 9   19-06  Thailand  37684
# 10  19-07  Thailand  37278
# 11  19-09  Thailand  36052
# 12  19-08  Thailand  32830
# 13  20-02  Thailand  31777
# 14  20-03  Thailand   2371
# 15  20-04  Thailand    299

# %%
df_Thai1 = df_Thai.sort_values(by=['년_월'])
df_Thai1
# Out:
#       년_월        국가  방문자_수
# 6   19-01  Thailand  41334
# 7   19-02  Thailand  39220
# 3   19-03  Thailand  53100
# 0   19-04  Thailand  69726
# 4   19-05  Thailand  52660
# 9   19-06  Thailand  37684
# 10  19-07  Thailand  37278
# 12  19-08  Thailand  32830
# 11  19-09  Thailand  36052
# 1   19-10  Thailand  65878
# 5   19-11  Thailand  49998
# 2   19-12  Thailand  55850
# 8   20-01  Thailand  38466
# 13  20-02  Thailand  31777
# 14  20-03  Thailand   2371
# 15  20-04  Thailand    299

# %%
con = m.connect(host='localhost', user='root', passwd='1234', db='project', charset='utf8')
cur = con.cursor()
q = "select 년_월, 국가, 방문자_수 from project_csv where 국가='Phillipines' order by 방문자_수 desc;"
cur.execute(q)
res = cur.fetchall()
col = ["년_월", "국가", "방문자_수"]
df_philli = pd.DataFrame(res, columns = col)
con.close()
df_philli
# Out:
#       년_월           국가  방문자_수
# 0   19-04  Phillipines  66525
# 1   19-10  Phillipines  55394
# 2   19-05  Phillipines  50569
# 3   19-12  Phillipines  43281
# 4   19-08  Phillipines  41817
# 5   19-11  Phillipines  41739
# 6   19-06  Phillipines  40748
# 7   19-03  Phillipines  38701
# 8   19-09  Phillipines  36252
# 9   20-01  Phillipines  30702
# 10  19-01  Phillipines  30473
# 11  19-02  Phillipines  29294
# 12  19-07  Phillipines  29074
# 13  20-02  Phillipines  20332
# 14  20-03  Phillipines   4539
# 15  20-04  Phillipines   1130

# %%
df_philli1 = df_philli.sort_values(by=['년_월'])
df_philli1
# Out:
#       년_월           국가  방문자_수
# 10  19-01  Phillipines  30473
# 11  19-02  Phillipines  29294
# 7   19-03  Phillipines  38701
# 0   19-04  Phillipines  66525
# 2   19-05  Phillipines  50569
# 6   19-06  Phillipines  40748
# 12  19-07  Phillipines  29074
# 4   19-08  Phillipines  41817
# 8   19-09  Phillipines  36252
# 1   19-10  Phillipines  55394
# 5   19-11  Phillipines  41739
# 3   19-12  Phillipines  43281
# 9   20-01  Phillipines  30702
# 13  20-02  Phillipines  20332
# 14  20-03  Phillipines   4539
# 15  20-04  Phillipines   1130

# %%
con = m.connect(host='localhost', user='root', passwd='1234', db='project', charset='utf8')
cur = con.cursor()
q = "select 년_월, 국가, 방문자_수 from project_csv where 국가='Vietnam' order by 방문자_수 desc;"
cur.execute(q)
res = cur.fetchall()
col = ["년_월", "국가", "방문자_수"]
df_Viet = pd.DataFrame(res, columns = col)
con.close()
df_Viet
# Out:
#       년_월       국가  방문자_수
# 0   19-10  Vietnam  64820
# 1   19-04  Vietnam  63169
# 2   19-06  Vietnam  58339
# 3   19-07  Vietnam  52521
# 4   19-03  Vietnam  46991
# 5   19-05  Vietnam  44416
# 6   19-09  Vietnam  43617
# 7   19-08  Vietnam  43583
# 8   19-11  Vietnam  43190
# 9   19-02  Vietnam  42181
# 10  19-12  Vietnam  30721
# 11  20-02  Vietnam  30313
# 12  20-01  Vietnam  30232
# 13  19-01  Vietnam  20183
# 14  20-04  Vietnam   6597
# 15  20-03  Vietnam   4048

# %%
df_Viet1 = df_Viet.sort_values(by=['년_월'])
df_Viet1
# Out:
#       년_월       국가  방문자_수
# 13  19-01  Vietnam  20183
# 9   19-02  Vietnam  42181
# 4   19-03  Vietnam  46991
# 1   19-04  Vietnam  63169
# 5   19-05  Vietnam  44416
# 2   19-06  Vietnam  58339
# 3   19-07  Vietnam  52521
# 7   19-08  Vietnam  43583
# 6   19-09  Vietnam  43617
# 0   19-10  Vietnam  64820
# 8   19-11  Vietnam  43190
# 10  19-12  Vietnam  30721
# 12  20-01  Vietnam  30232
# 11  20-02  Vietnam  30313
# 15  20-03  Vietnam   4048
# 14  20-04  Vietnam   6597

# %%
con = m.connect(host='localhost', user='root', passwd='1234', db='project', charset='utf8')
cur = con.cursor()
q = "select 년_월, 국가, 방문자_수 from project_csv where 국가='Malaysia' order by 방문자_수 desc;"
cur.execute(q)
res = cur.fetchall()
col = ["년_월", "국가", "방문자_수"]
df_Mal = pd.DataFrame(res, columns = col)
con.close()
df_Mal
# Out:
#       년_월        국가  방문자_수
# 0   19-12  Malaysia  57764
# 1   19-11  Malaysia  49282
# 2   19-10  Malaysia  45354
# 3   19-04  Malaysia  43726
# 4   19-03  Malaysia  40789
# 5   19-05  Malaysia  31217
# 6   19-09  Malaysia  28020
# 7   20-01  Malaysia  27549
# 8   19-02  Malaysia  27484
# 9   19-06  Malaysia  25538
# 10  19-01  Malaysia  22065
# 11  19-08  Malaysia  20520
# 12  20-02  Malaysia  18541
# 13  19-07  Malaysia  16831
# 14  20-03  Malaysia    890
# 15  20-04  Malaysia    152

# %%
df_Mal1 = df_Mal.sort_values(by=['년_월'])
df_Mal1
# Out:
#       년_월        국가  방문자_수
# 10  19-01  Malaysia  22065
# 8   19-02  Malaysia  27484
# 4   19-03  Malaysia  40789
# 3   19-04  Malaysia  43726
# 5   19-05  Malaysia  31217
# 9   19-06  Malaysia  25538
# 13  19-07  Malaysia  16831
# 11  19-08  Malaysia  20520
# 6   19-09  Malaysia  28020
# 2   19-10  Malaysia  45354
# 1   19-11  Malaysia  49282
# 0   19-12  Malaysia  57764
# 7   20-01  Malaysia  27549
# 12  20-02  Malaysia  18541
# 14  20-03  Malaysia    890
# 15  20-04  Malaysia    152

# %%
con = m.connect(host='localhost', user='root', passwd='1234', db='project', charset='utf8')
cur = con.cursor()
q = "select 년_월, 국가, 방문자_수 from project_csv where 국가='Singapore' order by 방문자_수 desc;"
cur.execute(q)
res = cur.fetchall()
col = ["년_월", "국가", "방문자_수"]
df_Sp = pd.DataFrame(res, columns = col)
con.close()
df_Sp
# Out:
#       년_월         국가  방문자_수
# 0   19-12  Singapore  42216
# 1   19-11  Singapore  27546
# 2   19-06  Singapore  24743
# 3   19-10  Singapore  24719
# 4   19-04  Singapore  23307
# 5   19-03  Singapore  22105
# 6   19-05  Singapore  20114
# 7   19-09  Singapore  17745
# 8   19-08  Singapore  13008
# 9   19-07  Singapore  10992
# 10  20-01  Singapore  10738
# 11  19-01  Singapore   9855
# 12  19-02  Singapore   9792
# 13  20-02  Singapore   5909
# 14  20-03  Singapore    219
# 15  20-04  Singapore     48

# %%
df_Sp1 = df_Sp.sort_values(by=['년_월'])
df_Sp1
# Out:
#       년_월         국가  방문자_수
# 11  19-01  Singapore   9855
# 12  19-02  Singapore   9792
# 5   19-03  Singapore  22105
# 4   19-04  Singapore  23307
# 6   19-05  Singapore  20114
# 2   19-06  Singapore  24743
# 9   19-07  Singapore  10992
# 8   19-08  Singapore  13008
# 7   19-09  Singapore  17745
# 3   19-10  Singapore  24719
# 1   19-11  Singapore  27546
# 0   19-12  Singapore  42216
# 10  20-01  Singapore  10738
# 13  20-02  Singapore   5909
# 14  20-03  Singapore    219
# 15  20-04  Singapore     48

# %%
result1 = pd.concat([df_ch, df_jp, df_Tai, df_USA, df_HK, df_Thai, df_philli, 
                     df_Viet, df_Mal, df_Sp])
result1
# Out:
#       년_월         국가   방문자_수
# 0   19-08      China  578112
# 1   19-10      China  567695
# 2   19-09      China  541350
# 3   19-07      China  519132
# 4   19-12      China  508877
# ..    ...        ...     ...
# 11  19-01  Singapore    9855
# 12  19-02  Singapore    9792
# 13  20-02  Singapore    5909
# 14  20-03  Singapore     219
# 15  20-04  Singapore      48
#
# [159 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.rc("font", family="Malgun Gothic")
plt.rc("axes", unicode_minus=False)

# %%
# 국가별 년_월에 따른 방문자_수의 변화 그래프

plt.figure(figsize=(6,6))
sns.lineplot(x='년_월', y='방문자_수', data=df_ch1, marker='o', label = '중국')
sns.lineplot(x='년_월', y='방문자_수', data=df_jp1, marker='o', label = '일본')
sns.lineplot(x='년_월', y='방문자_수', data=df_Tai1, marker='o', label = '대만')
sns.lineplot(x='년_월', y='방문자_수', data=df_USA1, marker='o', label = '미국')
sns.lineplot(x='년_월', y='방문자_수', data=df_HK1, marker='o', label = '홍콩')
sns.lineplot(x='년_월', y='방문자_수', data=df_Thai1, marker='o', label = '태국')
sns.lineplot(x='년_월', y='방문자_수', data=df_philli1, marker='o', label = '필리핀')
sns.lineplot(x='년_월', y='방문자_수', data=df_Viet1, marker='o', label = '베트남')
sns.lineplot(x='년_월', y='방문자_수', data=df_Mal1, marker='o', label = '말레이시아')
sns.lineplot(x='년_월', y='방문자_수', data=df_Sp1, marker='o', label = '싱가포르')

# 제목 추가하기
plt.title("Visitor_nation", family = "Courier New", color = 'black', weight = 'bold', size = 20)

# x축 라벨추가하기
plt.xlabel('년_월', color = 'black', weight = 'bold', size = 15)
plt.xticks(rotation=45)
# y축 라벨추가하기
plt.ylabel('방문자_수', color = 'black', weight = 'bold', size = 15)

plt.legend()
plt.show()
